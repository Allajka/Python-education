# %%
# f(x) = 5x^2 + 10x - 30

# %%
from sympy import *
from sympy.plotting import plot
from math import *
init_printing()

# %%
x = symbols('x')

# %%
f = 5*(x)**2 + 10*x - 30

# %% [markdown]
# # 1. Определить корни

# %%
roots_f = real_roots(f)
a, b = round(float(roots_f[0]), 3), round(float(roots_f[1]), 3)
print(f"Корни ({a}, {b}) ")
# Out:
# Корни (-3.646, 1.646)

# %% [markdown]
# # 2. Найти интервалы, на которых функция возрастает
# # 3. Найти интервалы, на которых функция убывает

# %%
derivative = str(diff(f))
dot = int(solve(derivative)[0])
def interval(derivative, dot):
    list_values = []
    for i in [str(dot-1), str(dot), str(dot+1)]:
        list_values.append(eval(derivative.replace("x", i))) 
    if list_values[0] < 0:
        print(f"Убывает (-oo ; {dot}) \nВозрастает ({dot} ; +oo)")
    else:
        print(f"Возрастает (-oo ; {dot}) \nУбывает ({dot} ; +oo)")

interval(derivative, dot)
# Out:
# Убывает (-oo ; -1)
# Возрастает (-1 ; +oo)

# %% [markdown]
# # 4. Построить график

# %%
plot(f, (x, -10, 10),line_color='red', title='График f(x) = 5x^2 + 10x - 30')
print(f)
# Out:
# 5*x**2 + 10*x - 30

# %% [markdown]
# # 5. Вычислить вершину

# %%
degree = degree(5*x**2 + 10*x - 30, gen=x)

# %%
import nums_from_string
sentence = str(srepr(5*x**2 + 10*x - 30))
coefficient = nums_from_string.get_nums(sentence)

# %%
index = 1
for i in range(degree, 1, -1):
    if i == coefficient[index]:
        del coefficient[index]
    index +=1

# %%
vertex_a = -(coefficient[1]/(2*coefficient[0]))
vertex_b = (((4*coefficient[0]*coefficient[2])-coefficient[1]**2))/4/coefficient[0]
print(f"Вершина параболы ({vertex_a};{vertex_b})")
# Out:
# Вершина параболы (-1.0;-35.0)

# %% [markdown]
# # 6. Определить промежутки, на котором f > 0
# # 7. Определить промежутки, на котором f < 0

# %%
def positively_negative(a,b,f):
    list_values = []
    list_values.append(eval(f.replace("x", str(a-1))))
    list_values.append(eval(f.replace("x", str(a+1))))
    list_values.append(eval(f.replace("x", str(b+1))))
    if list_values[0] > 0 and list_values[2] > 0:
        print(f"Промежутки, на котором f > 0:  (-oo ; {a}) u ({b} ; +oo) ")
        print(f"Промежутки, на котором f < 0:  ({a} ; {b})")
    else:
        print(f"Промежутки, на котором f > 0:  ({a} ; {b}) ")
        print(f"Промежутки, на котором f < 0:  (-oo ; {a}) u ({b} ; +oo)")        

f = "5*(x)**2 + 10*x - 30"
positively_negative(a,b,f)
# Out:
# Промежутки, на котором f > 0:  (-oo ; -3.646) u (1.646 ; +oo)
# Промежутки, на котором f < 0:  (-3.646 ; 1.646)
